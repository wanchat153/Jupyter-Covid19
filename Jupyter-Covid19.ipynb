# %% [markdown]
# # Welcome to Jupyter!

# %%
import requests
import io
import pandas as pd #ใช้ pandas ตั้งชื่อเป็น pd
url1 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-01-2020.csv")
url2 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-02-2020.csv")
url3 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-03-2020.csv")
url4 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-04-2020.csv")
url5 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-05-2020.csv")
url6 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-06-2020.csv")
url7 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-07-2020.csv")
url8 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-08-2020.csv")
url9 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-09-2020.csv")
url10 = pd.read_csv("https://raw.githubusercontent.com/CSSEGISandData/COVID-19/master/csse_covid_19_data/csse_covid_19_daily_reports/04-10-2020.csv")

# %%
#ข้อที่ 1 นับจำนวน Record ทั้งหมด
url = [url1, url2, url3, url4, url5, url6, url7, url8, url9, url10] #url คือ url1-url10
test = pd.concat(url) #เอามาเรียงต่อกัน
test.count() #นับจำนวนทั้งหมด
# Out:
# FIPS              19448
# Admin2            19587
# Province_State    23051
# Country_Region    24573
# Last_Update       27514
# Lat               21331
# Long_             21331
# Confirmed         24658
# Deaths            24573
# Recovered         21717
# Active            21717
# Combined_Key      21717
# dtype: int64

# %%
#ข้อที่ 2 จำนวนผู้เสียชีวิต(Death) ระหว่างวันที่ 1 - 2 เมษายน 2563
url = [url1, url2] #url คือ url1-url2
test = pd.concat(url) #เอามาเรียงต่อกัน
test = pd.DataFrame(test, columns= ['Last_Update','Deaths']) #แสดงจำนวนคนที่เสียชีวิต วันที่1-2
test #เรียกใช้test
# Out:
#               Last_Update  Deaths
# 0     2020-04-01 21:58:49       0
# 1     2020-04-01 21:58:49       1
# 2     2020-04-01 21:58:49       0
# 3     2020-04-01 21:58:49       3
# 4     2020-04-01 21:58:49       0
# ...                   ...     ...
# 2564         4/2/20 23:25       0
# 2565         4/2/20 23:25       1
# 2566         4/2/20 23:25       1
# 2567         4/2/20 23:25       1
# 2568         4/2/20 23:25       0
#
# [5052 rows x 2 columns]

# %%
#ข้อที่ 3 จำนวนผู้เสียชีวิต(Death) ประเทศไทย(Thailand) วันที่ 7 เมษายน 2563
url7 = pd.DataFrame(url7, columns= ['Last_Update','Deaths','Country_Region']) #แสดงจำนวนคนที่เสียชีวิต วันที่7 และประเทศ
test = url7.loc[(url7['Country_Region'] == 'Thailand')] #ในประเทศไทย
test #เรียกใช้test
# Out:
#               Last_Update  Deaths Country_Region
# 2838  2020-04-07 23:04:29      27       Thailand

# %%
#ข้อที่ 4 จำนวนผู้รักษาหาย(Recovered) ระหว่างวันที่ 1 - 2 เมษายน 2563
url = [url1, url2] #url คือ url1-url2
test = pd.concat(url) #เอามาเรียงต่อกัน
test2 = pd.DataFrame(test, columns= ['Last_Update','Recovered']) #แสดงจำนวนคนที่ผู้รักษาหาย วันที่1-2
test2 #เรียกใช้test2
# Out:
#               Last_Update  Recovered
# 0     2020-04-01 21:58:49          0
# 1     2020-04-01 21:58:49          0
# 2     2020-04-01 21:58:49          0
# 3     2020-04-01 21:58:49          0
# 4     2020-04-01 21:58:49          0
# ...                   ...        ...
# 2564         4/2/20 23:25         75
# 2565         4/2/20 23:25         18
# 2566         4/2/20 23:25          0
# 2567         4/2/20 23:25          0
# 2568         4/2/20 23:25          0
#
# [5052 rows x 2 columns]

# %%
#ข้อที่ 5 จำนวนผู้ติดเชื้อ(Confirmed) รัฐ Wisconsin (Province_State) ในวันที่ 10 เมษายน 2563
url10 = pd.DataFrame(url10, columns= ['Province_State','Last_Update','Confirmed']) #รัฐ และวันที่ ผู้ติดเชื้อ
test = url10.loc[(url10['Province_State'] == 'Wisconsin')] #ในรัฐ Wisconsin
test #เรียกใช้test
# Out:
#      Province_State          Last_Update  Confirmed
# 17        Wisconsin  2020-04-10 22:54:07          2
# 76        Wisconsin  2020-04-10 22:54:07          1
# 116       Wisconsin  2020-04-10 22:54:07          6
# 130       Wisconsin  2020-04-10 22:54:07          3
# 240       Wisconsin  2020-04-10 22:54:07         55
# ...             ...                  ...        ...
# 2538      Wisconsin  2020-04-10 22:54:07        193
# 2539      Wisconsin  2020-04-10 22:54:07          3
# 2540      Wisconsin  2020-04-10 22:54:07          2
# 2615      Wisconsin  2020-04-10 22:54:07         25
# 2626      Wisconsin  2020-04-10 22:54:07          2
#
# [64 rows x 3 columns]

# %%
#ข้อที่ 6  แสดงข้อมูลทั้งหมด
url = [url1, url2, url3, url4, url5, url6, url7, url8, url9, url10] #url คือ url1-url10
test = pd.concat(url) #เอามาเรียงต่อกัน
test #เรียกใช้test
# Out:
#          FIPS     Admin2  Province_State Country_Region          Last_Update  \
# 0     45001.0  Abbeville  South Carolina             US  2020-04-01 21:58:49
# 1     22001.0     Acadia       Louisiana             US  2020-04-01 21:58:49
# 2     51001.0   Accomack        Virginia             US  2020-04-01 21:58:49
# 3     16001.0        Ada           Idaho             US  2020-04-01 21:58:49
# 4     19001.0      Adair            Iowa             US  2020-04-01 21:58:49
# ...       ...        ...             ...            ...                  ...
# 2936      NaN        NaN             NaN            NaN  2020-04-10 22:53:48
# 2937      NaN        NaN             NaN            NaN  2020-04-10 22:53:48
# 2938      NaN        NaN             NaN            NaN  2020-04-10 22:53:48
# 2939      NaN        NaN             NaN            NaN  2020-04-10 22:53:48
# 2940      NaN        NaN            Utah            NaN  2020-04-10 22:54:07
#
# ...

# %%
#ข้อที่ 7 จำนวนผู้รักษาหาย(Recovered) ประเทศไทย(Thailand) วันที่ 8-9 เมษายน 2563
url = [url8, url9] #url คือ url1-url2
test = pd.concat(url) #เอามาเรียงต่อกัน
test2 = pd.DataFrame(test, columns= ['Country_Region','Last_Update','Recovered']) #ใช้ ประเทศ, วันที่และผู้รักษาหาย
test3 = test2.loc[(test2['Country_Region'] == 'Thailand')] #ในประเทศไทย
test3 #เรียกใช้test3
# Out:
#      Country_Region          Last_Update  Recovered
# 2864       Thailand  2020-04-08 22:51:39        888
# 2892       Thailand  2020-04-09 23:02:19        940

# %%
#ข้อที่ 8 จำนวนผู้เสียชีวิต(Death) ประเทศไทย(US) วันที่ 9-10 เมษายน 2563
url = [url9, url10] #url คือ url1-url2
test = pd.concat(url) #เอามาเรียงต่อกัน
test2 = pd.DataFrame(test, columns= ['Country_Region','Last_Update','Deaths']) #ใช้ ประเทศ, วันที่และผู้เสียชีวิต
test3 = test2.loc[(test2['Country_Region'] == 'US')] #ในประเทศUS
test3 #เรียกใช้test3
# Out:
#      Country_Region          Last_Update  Deaths
# 0                US  2020-04-09 23:02:37     0.0
# 1                US  2020-04-09 23:02:37     3.0
# 2                US  2020-04-09 23:02:37     0.0
# 3                US  2020-04-09 23:02:37     5.0
# 4                US  2020-04-09 23:02:37     0.0
# ...             ...                  ...     ...
# 2668             US  2020-04-09 23:02:37     4.0
# 2695             US  2020-04-09 23:02:37     2.0
# 2701             US  2020-04-09 23:02:37    33.0
# 2706             US  2020-04-09 23:02:37     0.0
# 2724             US  2020-04-09 23:02:37     1.0
#
# [2648 rows x 3 columns]

# %% [markdown]
# This repo contains an introduction to [Jupyter](https://jupyter.org) and [IPython](https://ipython.org).
#
# Outline of some basics:
#
# * [Notebook Basics](../examples/Notebook/Notebook%20Basics.ipynb)
# * [IPython - beyond plain python](../examples/IPython%20Kernel/Beyond%20Plain%20Python.ipynb)
# * [Markdown Cells](../examples/Notebook/Working%20With%20Markdown%20Cells.ipynb)
# * [Rich Display System](../examples/IPython%20Kernel/Rich%20Output.ipynb)
# * [Custom Display logic](../examples/IPython%20Kernel/Custom%20Display%20Logic.ipynb)
# * [Running a Secure Public Notebook Server](../examples/Notebook/Running%20the%20Notebook%20Server.ipynb#Securing-the-notebook-server)
# * [How Jupyter works](../examples/Notebook/Multiple%20Languages%2C%20Frontends.ipynb) to run code in different languages.

# %% [markdown]
# You can also get this tutorial and run it on your laptop:
#
#     git clone https://github.com/ipython/ipython-in-depth
#
# Install IPython and Jupyter:
#
# with [conda](https://www.anaconda.com/download):
#
#     conda install ipython jupyter
#
# with pip:
#
#     # first, always upgrade pip!
#     pip install --upgrade pip
#     pip install --upgrade ipython jupyter
#
# Start the notebook in the tutorial directory:
#
#     cd ipython-in-depth
#     jupyter notebook
